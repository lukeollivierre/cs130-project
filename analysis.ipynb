# %%
# Step 1: Load the CSV file
data = [] 
for line in open("Team_Attributes.csv"):
    data.append(line.strip().split(","))

# %%
print("\nBuildUpPlaySpeed column values:")
for row in data[1:]:
    if len(row) > speed_index:
        print(row[speed_index])
# Out:
# BuildUpPlaySpeed column values:
# 60
# 52
# 47
# 70
# 47
# 58
# 62
# 58
# 59
# 60
# 65
# 59
# 59
# 59
# 59
# 45
# 65
# 45
# 48
# 48
# 48
# 30
# 30
# 45
# 45
# 52
# 53
# 30
# 53
# 38
# 38
# 58
# 56
# 30
# 40
# 31
# 35
# 40
# 35
# 65
# 55
# 42
# 46
# 46
# 46
# 50
# 50
# 52
# 52
# 52
# 52
# 45
# 65
# 50
# 50
# 48
# 48
# 30
# 46
# 50
# 50
# 23
# 41
# 39
# 56
# 40
# 46
# 62
# 69
# 65
# 66
# 75
# 25
# 30
# 59
# 59
# 70
# 65
# 67
# 63
# 66
# 63
# 35
# 65
# 40
# 64
# 64
# 64
# 60
# 70
# 42
# 46
# 46
# 46
# 64
# 57
# 47
# 47
# 47
# 57
# 45
# 68
# 55
# 40
# 62
# 59
# 30
# 35
# 64
# 64
# 64
# 64
# 55
# 45
# 46
# 62
# 52
# 50
# 42
# 43
# 24
# 35
# 35
# 36
# 30
# 65
# 50
# 55
# 55
# 52
# 40
# 46
# 61
# 61
# 61
# 61
# 70
# 67
# 58
# 64
# 69
# 73
# 65
# 42
# 47
# 56
# 37
# 45
# 35
# 47
# 55
# 47
# 48
# 39
# 39
# 30
# 52
# 51
# 40
# 47
# 30
# 65
# 55
# 65
# 70
# 69
# 70
# 45
# 51
# 56
# 56
# 56
# 55
# 55
# 57
# 44
# 44
# 60
# 70
# 70
# 45
# 45
# 67
# 62
# 47
# 50
# 55
# 40
# 40
# 38
# 69
# 65
# 65
# ...

# %%
import pandas as pd
import numpy as np
attributes = pd.read_csv("Team_Attributes.csv")

# %%
attributes.shape
# Out:
# (1458, 25)

# %%
attributes.head()
# Out:
#    id  team_fifa_api_id  team_api_id                 date  buildUpPlaySpeed  \
# 0   1               434         9930  2010-02-22 00:00:00                60
# 1   2               434         9930  2014-09-19 00:00:00                52
# 2   3               434         9930  2015-09-10 00:00:00                47
# 3   4                77         8485  2010-02-22 00:00:00                70
# 4   5                77         8485  2011-02-22 00:00:00                47
#
#   buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0              Balanced                   NaN                    Little
# 1              Balanced                  48.0                    Normal
# 2              Balanced                  41.0                    Normal
# 3                  Fast                   NaN                    Little
# 4              Balanced                   NaN                    Little
#
# ...

# %%
attributes.team_api_id
# Out:
# 0        9930
# 1        9930
# 2        9930
# 3        8485
# 4        8485
#         ...
# 1453    10000
# 1454    10000
# 1455    10000
# 1456    10000
# 1457    10000
# Name: team_api_id, Length: 1458, dtype: int64

# %%
attributes['team_api_id']
# Out:
# 0        9930
# 1        9930
# 2        9930
# 3        8485
# 4        8485
#         ...
# 1453    10000
# 1454    10000
# 1455    10000
# 1456    10000
# 1457    10000
# Name: team_api_id, Length: 1458, dtype: int64

# %%
print(attributes['team_api_id'][3])
# Out:
# 8485

# %%
attributes.iloc[2]
# Out:
# id                                                  3
# team_fifa_api_id                                  434
# team_api_id                                      9930
# date                              2015-09-10 00:00:00
# buildUpPlaySpeed                                   47
# buildUpPlaySpeedClass                        Balanced
# buildUpPlayDribbling                             41.0
# buildUpPlayDribblingClass                      Normal
# buildUpPlayPassing                                 54
# buildUpPlayPassingClass                         Mixed
# buildUpPlayPositioningClass                 Organised
# chanceCreationPassing                              54
# chanceCreationPassingClass                     Normal
# chanceCreationCrossing                             63
# chanceCreationCrossingClass                    Normal
# chanceCreationShooting                             64
# chanceCreationShootingClass                    Normal
# ...

# %%
print(attributes.iloc[:2,2])
# Out:
# 0    9930
# 1    9930
# Name: team_api_id, dtype: int64

# %%
attributes.defenceAggression > 45
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1453     True
# 1454     True
# 1455     True
# 1456     True
# 1457     True
# Name: defenceAggression, Length: 1458, dtype: bool
